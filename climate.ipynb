# %% [markdown]
# <a href="https://colab.research.google.com/github/lukystrikeibg/python/blob/master/climate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import numpy as np
import pandas as pd

# %%
 from google.colab import drive
drive.mount('/content/drive' )
# Out:
# Mounted at /content/drive

# %%
# %cd '/content/drive/My Drive/Colab Notebooks/manipulación de datos/de'
# !ls
# Out:
# /content/drive/My Drive/Colab Notebooks/manipulación de datos/de
#  bicicletas-compartidas.csv   CNPV2018_2HOG_A2_11.CSV
# 'climate 2012-2016.csv'       CNPV2018_3FALL_A2_11.CSV
#  CNPV2018_1VIV_A2_11.CSV      DailyDelhiClimateTrain.csv

# %%
 df_climate=pd.read_csv('DailyDelhiClimateTrain.csv')
df_climate.sample(20)
# Out:
#             date   meantemp   humidity  wind_speed  meanpressure
# 1452  2016-12-23  15.550000  74.700000    1.205000   1014.250000
# 712   2014-12-14  16.875000  86.625000    3.950000   1014.500000
# 82    2013-03-24  27.000000  48.750000   10.887500   1010.250000
# 855   2015-05-06  34.125000  22.000000   11.362500   1001.875000
# 408   2014-02-13  15.250000  64.500000    4.875000   1013.625000
# 486   2014-05-02  34.375000  24.750000    6.487500   1001.875000
# 112   2013-04-23  28.625000  44.125000    4.625000   1009.875000
# 1386  2016-10-18  28.500000  48.458333    7.668182   1009.458333
# 1057  2015-11-24  18.500000  63.000000    1.625000   1016.000000
# 615   2014-09-08  31.250000  66.375000    3.475000   1003.125000
# 966   2015-08-25  32.000000  57.285714   10.071429   1001.000000
# 1308  2016-08-01  29.125000  84.250000    5.912500    999.125000
# 452   2014-03-29  25.875000  55.625000    8.350000   1011.250000
# ...

# %%
df_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   datetime64[ns]
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 57.2 KB

# %%
df_climate['date']=pd.to_datetime(df_climate['date'])

# %%
list(df_climate)
# Out:
# ['date', 'meantemp', 'humidity', 'wind_speed', 'meanpressure']

# %%
df_climate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1462 entries, 0 to 1461
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   date          1462 non-null   datetime64[ns]
#  1   meantemp      1462 non-null   float64
#  2   humidity      1462 non-null   float64
#  3   wind_speed    1462 non-null   float64
#  4   meanpressure  1462 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 57.2 KB

# %%
df_time=df_climate.groupby('date').sum()
df_time.head(10)
# Out:
#              meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000  84.500000    0.000000   1015.666667
# 2013-01-02   7.400000  92.000000    2.980000   1017.800000
# 2013-01-03   7.166667  87.000000    4.633333   1018.666667
# 2013-01-04   8.666667  71.333333    1.233333   1017.166667
# 2013-01-05   6.000000  86.833333    3.700000   1016.500000
# 2013-01-06   7.000000  82.800000    1.480000   1018.000000
# 2013-01-07   7.000000  78.600000    6.300000   1020.000000
# 2013-01-08   8.857143  63.714286    7.142857   1018.714286
# 2013-01-09  14.000000  51.250000   12.500000   1017.000000
# 2013-01-10  11.000000  62.000000    7.400000   1015.666667

# %%
df1=df_time['meantemp'].iloc[3:20]
df1
# Out:
# date
# 2013-01-04     8.666667
# 2013-01-05     6.000000
# 2013-01-06     7.000000
# 2013-01-07     7.000000
# 2013-01-08     8.857143
# 2013-01-09    14.000000
# 2013-01-10    11.000000
# 2013-01-11    15.714286
# 2013-01-12    14.000000
# 2013-01-13    15.833333
# 2013-01-14    12.833333
# 2013-01-15    14.714286
# 2013-01-16    13.833333
# 2013-01-17    16.500000
# 2013-01-18    13.833333
# 2013-01-19    12.500000
# 2013-01-20    11.285714
# Name: meantemp, dtype: float64

# %%
df2=df_time['wind_speed'].iloc[5:25]
df2
# Out:
# date
# 2013-01-06     1.480000
# 2013-01-07     6.300000
# 2013-01-08     7.142857
# 2013-01-09    12.500000
# 2013-01-10     7.400000
# 2013-01-11    10.571429
# 2013-01-12    13.228571
# 2013-01-13     4.633333
# 2013-01-14     0.616667
# 2013-01-15     0.528571
# 2013-01-16     0.000000
# 2013-01-17     5.250000
# 2013-01-18     8.950000
# 2013-01-19     5.883333
# 2013-01-20     8.471429
# 2013-01-21     2.220000
# 2013-01-22     3.083333
# 2013-01-23     4.016667
# 2013-01-24     6.166667
# 2013-01-25     5.550000
# Name: wind_speed, dtype: float64

# %%
df_12=(df2/df1).ffill() # bfill y ffill traen el valor previo o el adelante al valor nulo
df_12
# Out:
# date
# 2013-01-04         NaN
# 2013-01-05         NaN
# 2013-01-06    0.211429
# 2013-01-07    0.900000
# 2013-01-08    0.806452
# 2013-01-09    0.892857
# 2013-01-10    0.672727
# 2013-01-11    0.672727
# 2013-01-12    0.944898
# 2013-01-13    0.292632
# 2013-01-14    0.048052
# 2013-01-15    0.035922
# 2013-01-16    0.000000
# 2013-01-17    0.318182
# 2013-01-18    0.646988
# 2013-01-19    0.470667
# 2013-01-20    0.750633
# 2013-01-21    0.750633
# 2013-01-22    0.750633
# 2013-01-23    0.750633
# 2013-01-24    0.750633
# 2013-01-25    0.750633
# dtype: float64

# %%
df_time.diff()## restar dato con el dato anterior
# Out:
#             meantemp   humidity  wind_speed  meanpressure
# date
# 2013-01-01       NaN        NaN         NaN           NaN
# 2013-01-02 -2.600000   7.500000    2.980000      2.133333
# 2013-01-03 -0.233333  -5.000000    1.653333      0.866667
# 2013-01-04  1.500000 -15.666667   -3.400000     -1.500000
# 2013-01-05 -2.666667  15.500000    2.466667     -0.666667
# ...              ...        ...         ...           ...
# 2016-12-28  0.367391   0.493478   -4.787174     -1.634783
# 2016-12-29 -1.979296  19.813665    2.452174      1.339545
# 2016-12-30 -1.142857   1.809524    0.266667      1.000000
# 2016-12-31  0.957393  -2.666667    1.058333     -1.804762
# 2017-01-01 -5.052632  13.000000   -7.325000     -0.100000
#
# [1462 rows x 4 columns]

# %%
df_a=df_time.resample('M').sum().iloc[:10]
df_a
# Out:
#                meantemp     humidity  wind_speed  meanpressure
# date
# 2013-01-31   374.317857  2263.892857  149.851310  31553.279762
# 2013-02-28   472.291667  2014.279762  209.274524  28446.488095
# 2013-03-31   707.240476  1779.934524  271.475357  31363.751190
# 2013-04-30   866.853571  1038.363095  241.391548  30188.770238
# 2013-05-31  1047.079762   897.085714  277.247024  30997.650000
# 2013-06-30   974.426190  1762.744048  287.817857  29922.265476
# 2013-07-31   950.571429  2321.075000  228.119643  30918.789286
# 2013-08-31   915.980952  2379.470238  228.914762  31013.639286
# 2013-09-30   895.217857  1936.582143  227.802738  30118.475000
# 2013-10-31   810.004762  2177.923810   87.919405  31305.314286

# %%
df_i=df_12.interpolate()
df_i
# Out:
# date
# 2013-01-04         NaN
# 2013-01-05         NaN
# 2013-01-06    0.211429
# 2013-01-07    0.900000
# 2013-01-08    0.806452
# 2013-01-09    0.892857
# 2013-01-10    0.672727
# 2013-01-11    0.672727
# 2013-01-12    0.944898
# 2013-01-13    0.292632
# 2013-01-14    0.048052
# 2013-01-15    0.035922
# 2013-01-16    0.000000
# 2013-01-17    0.318182
# 2013-01-18    0.646988
# 2013-01-19    0.470667
# 2013-01-20    0.750633
# 2013-01-21    0.750633
# 2013-01-22    0.750633
# 2013-01-23    0.750633
# 2013-01-24    0.750633
# 2013-01-25    0.750633
# dtype: float64

# %%
df_time.plot('meantemp')
df_time.plot('humidity')

# %%
df_hot=df_time.groupby('date')['meantemp'].max().sort_values(ascending=False)
df_hot
# Out:
# date
# 2013-05-25    38.714286
# 2014-06-07    38.500000
# 2013-05-24    38.428571
# 2016-05-27    38.272727
# 2016-06-04    38.200000
#                 ...
# 2013-01-02     7.400000
# 2013-01-03     7.166667
# 2013-01-07     7.000000
# 2013-01-06     7.000000
# 2013-01-05     6.000000
# Name: meantemp, Length: 1462, dtype: float64

# %%
df_hot.plot(figsize=(12,10))
